# %%
import tensorflow as tf
import numpy as np
import os
import scipy.io as spio
from matplotlib import pyplot as plt
from imageio import imread

# %% [markdown]
# #### Obs: If you only have one of the datasets (does not matter which one), just run all the notebook's cells and it will work just fine.

# %%
# define base paths for pascal the original VOC dataset training images
base_dataset_dir_voc = '/Users/udaysawhney/Desktop/segmentation/deeplab_v3-master/dataset/VOCdevkit/VOC2012/'
images_folder_name_voc = "JPEGImages/"
annotations_folder_name_voc = "Annotations/"
images_dir_voc = os.path.join(base_dataset_dir_voc, images_folder_name_voc)
print(images_dir_voc)
annotations_dir_voc = os.path.join(base_dataset_dir_voc, annotations_folder_name_voc)
# Out:
# /Users/udaysawhney/Desktop/segmentation/deeplab_v3-master/dataset/VOCdevkit/VOC2012/JPEGImages/

# %%
# define base paths for pascal augmented VOC images
# download: http://home.bharathh.info/pubs/codes/SBD/download.html
base_dataset_dir_aug_voc = '<pascal/augmented/VOC/images/path>/benchmark_RELEASE/dataset'
images_folder_name_aug_voc = "img/"
annotations_folder_name_aug_voc = "cls/"
images_dir_aug_voc = os.path.join(base_dataset_dir_aug_voc, images_folder_name_aug_voc)
annotations_dir_aug_voc = os.path.join(base_dataset_dir_aug_voc, annotations_folder_name_aug_voc)

# %%
def get_files_list(base_dataset_dir, images_folder_name, annotations_folder_name, filename):
    images_dir = os.path.join(base_dataset_dir, images_folder_name)
    annotations_dir = os.path.join(base_dataset_dir, annotations_folder_name)

    file = open(filename, 'r')
    images_filename_list = [line for line in file]
    return images_filename_list

# %%
images_filename_list = get_files_list(base_dataset_dir_aug_voc, images_folder_name_aug_voc, annotations_folder_name_aug_voc, "custom_train.txt")
print("Total number of training images:", len(images_filename_list))
# Out:
# Total number of training images: 8252

# %%
# shuffle array and separate 10% to validation
np.random.shuffle(images_filename_list)
val_images_filename_list = images_filename_list[:int(0.10*len(images_filename_list))]
train_images_filename_list = images_filename_list[int(0.10*len(images_filename_list)):]

# %%
print("train set size:", len(train_images_filename_list))
print("val set size:", len(val_images_filename_list))
# Out:
# train set size: 7427
# val set size: 825

# %%
TRAIN_DATASET_DIR="./tfrecords/"
if not os.path.exists(TRAIN_DATASET_DIR):
    os.mkdir(TRAIN_DATASET_DIR)
    
TRAIN_FILE = 'train.tfrecords'
VALIDATION_FILE = 'validation.tfrecords'
train_writer = tf.python_io.TFRecordWriter(os.path.join(TRAIN_DATASET_DIR,TRAIN_FILE))
val_writer = tf.python_io.TFRecordWriter(os.path.join(TRAIN_DATASET_DIR,VALIDATION_FILE))

# %%
def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

# %%
def read_annotation_from_mat_file(annotations_dir, image_name):
    annotations_path = os.path.join(annotations_dir, (image_name.strip() + ".xml"))
    mat = spio.loadmat(annotations_path)
    img = mat['GTcls']['Segmentation'][0][0]
    return img

# %%
for i, image_name in enumerate(train_images_filename_list):
    image_np = imread(os.path.join(images_dir_voc, image_name.strip() + ".jpg"))

# %%
def create_tfrecord_dataset(filename_list, writer):

    # create training tfrecord
    read_imgs_counter = 0
    for i, image_name in enumerate(filename_list):
        image_name = str(image_name)

        try:
            image_np = imread(os.path.join(images_dir_aug_voc, image_name.strip() + ".jpg"))
        except FileNotFoundError:
            try:
                # read from Pascal VOC path
                image_np = imread(os.path.join(images_dir_voc, image_name.strip() + ".jpg"))
            except FileNotFoundError:
                print(os.path.join(images_dir_voc, image_name.strip() + ".jpg"))
                print("File:",image_name.strip(),"not found.")
                continue
        try:
            annotation_np = read_annotation_from_mat_file(annotations_dir_aug_voc, image_name)
        except FileNotFoundError:
            # read from Pascal VOC path
            try:
                annotation_np = imread(os.path.join(annotations_dir_voc, image_name.strip() + ".jpg"))
            except FileNotFoundError:
                print("File:",image_name.strip(),"not found.")
                continue
            
        read_imgs_counter += 1
        image_h = image_np.shape[0]
        image_w = image_np.shape[1]

        img_raw = image_np.tostring()
        annotation_raw = annotation_np.tostring()

        example = tf.train.Example(features=tf.train.Features(feature={
                'height': _int64_feature(image_h),
                'width': _int64_feature(image_w),
                'image_raw': _bytes_feature(img_raw),
                'annotation_raw': _bytes_feature(annotation_raw)}))

        writer.write(example.SerializeToString())
    
    print("End of TfRecord. Total of image written:", read_imgs_counter)
    writer.close()

# %%
# create training dataset
create_tfrecord_dataset(train_images_filename_list, train_writer)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat)
#      32     try:
# ---> 33         return open(file_like, 'rb'), True
#      34     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '<pascal/augmented/VOC/images/path>/benchmark_RELEASE/dataset/cls/2008_002259.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-656a7ada78fa> in create_tfrecord_dataset(filename_list, writer)
#      18         try:
# ---> 19             annotation_np = read_annotation_from_mat_file(annotations_dir_aug_voc, image_name)
#      20         except FileNotFoundError:
#
# <ipython-input-11-f033846eb6a6> in read_annotation_from_mat_file(annotations_dir, image_name)
#       2     annotations_path = os.path.join(annotations_dir, (image_name.strip() + ".mat"))
# ----> 3     mat = spio.loadmat(annotations_path)
#       4     img = mat['GTcls']['Segmentation'][0][0]
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     140     variable_names = kwargs.pop('variable_names', None)
# --> 141     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
#     142     matfile_dict = MR.get_variables(variable_names)
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/matlab/mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      63     """
# ---> 64     byte_stream, file_opened = _open_file(file_name, appendmat)
#      65     mjv, mnv = get_matfile_version(byte_stream)
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat)
#      38                 file_like += '.mat'
# ---> 39             return open(file_like, 'rb'), True
#      40         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '<pascal/augmented/VOC/images/path>/benchmark_RELEASE/dataset/cls/2008_002259.mat'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-458f2a368d22> in <module>()
#       1 # create training dataset
# ----> 2 create_tfrecord_dataset(train_images_filename_list, train_writer)
#
# <ipython-input-15-656a7ada78fa> in create_tfrecord_dataset(filename_list, writer)
#      21             # read from Pascal VOC path
#      22             try:
# ---> 23                 annotation_np = imread(os.path.join(annotations_dir_voc, image_name.strip() + ".xml"))
#      24             except FileNotFoundError:
#      25                 print("File:",image_name.strip(),"not found.")
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     219
#     220     # Get reader and read first
# --> 221     reader = read(uri, format, "i", **kwargs)
#     222     with reader:
#     223         return reader.get_data(0)
#
# /anaconda3/envs/tensorflow/lib/python3.6/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     137     if format is None:
#     138         raise ValueError(
# --> 139             "Could not find a format to read the specified file " "in mode %r" % mode
#     140         )
#     141
#
# ValueError: Could not find a format to read the specified file in mode 'i'

# %%
# create validation dataset
create_tfrecord_dataset(val_images_filename_list, val_writer)
# Out:
# File: 2009_000303 not found.
# File: 2008_005599 not found.
# File: 2009_002685 not found.
# File: 2008_006753 not found.
# File: 2010_002856 not found.
# File: 2011_002988 not found.
# File: 2007_005227 not found.
# File: 2009_004953 not found.
# File: 2010_004874 not found.
# File: 2008_001876 not found.
# File: 2008_005379 not found.
# File: 2008_006747 not found.
# File: 2009_004374 not found.
# File: 2008_007525 not found.
# File: 2010_001044 not found.
# File: 2010_003139 not found.
# File: 2011_002571 not found.
# File: 2007_001698 not found.
# File: 2010_005937 not found.
# File: 2010_000689 not found.
# File: 2010_002552 not found.
# File: 2009_001500 not found.
# File: 2008_005354 not found.
# File: 2009_001413 not found.
# File: 2007_003000 not found.
# File: 2009_003636 not found.
# File: 2010_001625 not found.
# File: 2008_002177 not found.
# File: 2010_000485 not found.
# File: 2008_005541 not found.
# File: 2010_001277 not found.
# File: 2008_003675 not found.
# File: 2010_003672 not found.
# File: 2011_001949 not found.
# File: 2008_008668 not found.
# File: 2010_005053 not found.
# File: 2009_003425 not found.
# File: 2008_000669 not found.
# File: 2008_002899 not found.
# File: 2008_008589 not found.
# File: 2009_001929 not found.
# File: 2009_003445 not found.
# File: 2010_002085 not found.
# File: 2009_004513 not found.
# File: 2009_001755 not found.
# File: 2010_002771 not found.
# File: 2008_006748 not found.
# File: 2011_000790 not found.
# File: 2008_003635 not found.
# File: 2010_001729 not found.
# File: 2011_000398 not found.
# File: 2008_007823 not found.
# File: 2008_003544 not found.
# File: 2009_000961 not found.
# File: 2009_003629 not found.
# File: 2008_007208 not found.
# File: 2011_001616 not found.
# File: 2008_002960 not found.
# File: 2010_003690 not found.
# File: 2008_001420 not found.
# File: 2010_005981 not found.
# File: 2008_002079 not found.
# File: 2009_004109 not found.
# File: 2009_002325 not found.
# File: 2008_006447 not found.
# File: 2010_002286 not found.
# File: 2008_004307 not found.
# File: 2009_002499 not found.
# File: 2008_001367 not found.
# File: 2011_003109 not found.
# File: 2008_004074 not found.
# File: 2009_000783 not found.
# File: 2010_005028 not found.
# File: 2008_002533 not found.
# File: 2010_003798 not found.
# File: 2010_005740 not found.
# File: 2011_001261 not found.
# File: 2008_000095 not found.
# File: 2008_002645 not found.
# File: 2008_000099 not found.
# File: 2010_005665 not found.
# File: 2009_003534 not found.
# File: 2007_005314 not found.
# File: 2009_000055 not found.
# File: 2007_008948 not found.
# File: 2010_004575 not found.
# File: 2007_008072 not found.
# File: 2009_001462 not found.
# File: 2010_001970 not found.
# File: 2008_005618 not found.
# File: 2008_001188 not found.
# File: 2008_007573 not found.
# File: 2011_002488 not found.
# File: 2010_001807 not found.
# File: 2009_000975 not found.
# File: 2011_003065 not found.
# File: 2008_007245 not found.
# File: 2008_008767 not found.
# File: 2008_001312 not found.
# File: 2010_000626 not found.
# File: 2010_004573 not found.
# File: 2008_002037 not found.
# File: 2008_004975 not found.
# File: 2010_001645 not found.
# File: 2008_008476 not found.
# File: 2008_000502 not found.
# File: 2009_002669 not found.
# File: 2009_004397 not found.
# File: 2009_002267 not found.
# File: 2010_000815 not found.
# File: 2010_005111 not found.
# File: 2008_005231 not found.
# File: 2011_001167 not found.
# File: 2008_005408 not found.
# File: 2008_006879 not found.
# File: 2009_002536 not found.
# File: 2008_002823 not found.
# File: 2010_001960 not found.
# File: 2009_004399 not found.
# File: 2008_007098 not found.
# File: 2009_004606 not found.
# File: 2009_005015 not found.
# File: 2008_005134 not found.
# File: 2011_002186 not found.
# File: 2009_002273 not found.
# File: 2011_001611 not found.
# File: 2008_008583 not found.
# File: 2010_005308 not found.
# File: 2009_002506 not found.
# File: 2008_003531 not found.
# File: 2009_002386 not found.
# File: 2008_007746 not found.
# File: 2011_001105 not found.
# File: 2010_005258 not found.
# File: 2011_000181 not found.
# File: 2009_000085 not found.
# File: 2011_002211 not found.
# File: 2011_003044 not found.
# File: 2010_003053 not found.
# File: 2011_000009 not found.
# File: 2010_001694 not found.
# File: 2008_001159 not found.
# File: 2010_005748 not found.
# File: 2010_000995 not found.
# File: 2009_000140 not found.
# File: 2010_004646 not found.
# File: 2008_006111 not found.
# File: 2008_001527 not found.
# File: 2010_002215 not found.
# File: 2008_003589 not found.
# File: 2011_000577 not found.
# File: 2008_006923 not found.
# File: 2008_000399 not found.
# File: 2008_005336 not found.
# File: 2010_000136 not found.
# File: 2010_004944 not found.
# File: 2009_003373 not found.
# File: 2010_004826 not found.
# File: 2009_002798 not found.
# File: 2009_003411 not found.
# File: 2010_001094 not found.
# File: 2007_005043 not found.
# File: 2009_000001 not found.
# File: 2010_005369 not found.
# File: 2010_002301 not found.
# File: 2008_008347 not found.
# File: 2010_002242 not found.
# File: 2008_004287 not found.
# File: 2008_003967 not found.
# File: 2008_000281 not found.
# File: 2009_001873 not found.
# File: 2008_004636 not found.
# File: 2010_005129 not found.
# File: 2008_005414 not found.
# File: 2009_001138 not found.
# File: 2009_003929 not found.
# File: 2009_002441 not found.
# File: 2009_003201 not found.
# File: 2011_001173 not found.
# File: 2011_002584 not found.
# File: 2008_006194 not found.
# File: 2008_003841 not found.
# File: 2009_000409 not found.
# File: 2010_001372 not found.
# File: 2011_001977 not found.
# File: 2008_006182 not found.
# File: 2009_003118 not found.
# File: 2007_002024 not found.
# File: 2009_002556 not found.
# File: 2008_001708 not found.
# File: 2010_003091 not found.
# File: 2011_000655 not found.
# File: 2010_004111 not found.
# File: 2008_000905 not found.
# File: 2009_002845 not found.
# File: 2010_000379 not found.
# File: 2011_002335 not found.
# File: 2008_005519 not found.
# File: 2010_005835 not found.
# File: 2010_000678 not found.
# File: 2009_003911 not found.
# File: 2009_001188 not found.
# File: 2009_000160 not found.
# File: 2011_001535 not found.
# File: 2010_005075 not found.
# File: 2008_001022 not found.
# File: 2009_004233 not found.
# File: 2008_004385 not found.
# File: 2011_001666 not found.
# File: 2008_006249 not found.
# File: 2008_003847 not found.
# File: 2010_000317 not found.
# File: 2008_001787 not found.
# File: 2009_003109 not found.
# File: 2010_004412 not found.
# File: 2010_005253 not found.
# File: 2009_003447 not found.
# File: 2009_002039 not found.
# File: 2011_001776 not found.
# File: 2010_002427 not found.
# File: 2010_005597 not found.
# File: 2008_006151 not found.
# File: 2011_000278 not found.
# File: 2008_003788 not found.
# File: 2010_004760 not found.
# File: 2011_000572 not found.
# File: 2009_001329 not found.
# File: 2008_005650 not found.
# File: 2010_001649 not found.
# File: 2008_000348 not found.
# File: 2010_001870 not found.
# File: 2009_001805 not found.
# File: 2010_002337 not found.
# File: 2007_002216 not found.
# File: 2010_001320 not found.
# File: 2011_001877 not found.
# File: 2007_002212 not found.
# File: 2008_008725 not found.
# File: 2010_000063 not found.
# File: 2009_002672 not found.
# File: 2008_001353 not found.
# File: 2008_000545 not found.
# File: 2008_007456 not found.
# File: 2010_002278 not found.
# File: 2007_003118 not found.
# File: 2010_002827 not found.
# File: 2007_004830 not found.
# File: 2007_006605 not found.
# File: 2010_004888 not found.
# File: 2008_001271 not found.
# File: 2011_000748 not found.
# File: 2009_005019 not found.
# File: 2010_000227 not found.
# File: 2009_002645 not found.
# File: 2010_002068 not found.
# File: 2007_003580 not found.
# File: 2008_003114 not found.
# File: 2009_000547 not found.
# File: 2008_005945 not found.
# File: 2008_004945 not found.
# File: 2008_008337 not found.
# File: 2009_002531 not found.
# File: 2010_000069 not found.
# File: 2010_004360 not found.
# File: 2010_002130 not found.
# File: 2008_001351 not found.
# File: 2009_002054 not found.
# File: 2008_008497 not found.
# File: 2010_003299 not found.
# File: 2011_001790 not found.
# File: 2008_005847 not found.
# File: 2011_002841 not found.
# File: 2011_001679 not found.
# File: 2010_005559 not found.
# File: 2010_003321 not found.
# File: 2010_004211 not found.
# File: 2010_000127 not found.
# File: 2009_001735 not found.
# File: 2009_000040 not found.
# File: 2008_006272 not found.
# File: 2009_003801 not found.
# File: 2008_002794 not found.
# File: 2010_002628 not found.
# File: 2010_000538 not found.
# File: 2008_003864 not found.
# File: 2009_000563 not found.
# File: 2008_002117 not found.
# File: 2010_001817 not found.
# File: 2011_001253 not found.
# File: 2008_000238 not found.
# File: 2008_004966 not found.
# File: 2009_001867 not found.
# File: 2011_002617 not found.
# File: 2010_002409 not found.
# File: 2010_003735 not found.
# File: 2007_000720 not found.
# File: 2008_005834 not found.
# File: 2009_001759 not found.
# File: 2008_000835 not found.
# File: 2010_003974 not found.
# File: 2010_002455 not found.
# File: 2008_001842 not found.
# File: 2011_002189 not found.
# File: 2008_008694 not found.
# File: 2010_002973 not found.
# File: 2010_000621 not found.
# File: 2008_001075 not found.
# File: 2008_000318 not found.
# File: 2008_003087 not found.
# File: 2010_004849 not found.
# File: 2008_002801 not found.
# File: 2011_000268 not found.
# File: 2009_001195 not found.
# File: 2008_007917 not found.
# File: 2010_004459 not found.
# File: 2011_002027 not found.
# File: 2008_007382 not found.
# File: 2010_002881 not found.
# File: 2008_005133 not found.
# File: 2008_000426 not found.
# File: 2009_003734 not found.
# File: 2009_000253 not found.
# File: 2010_003573 not found.
# File: 2008_008685 not found.
# File: 2010_005011 not found.
# File: 2008_000745 not found.
# File: 2010_003995 not found.
# File: 2009_003430 not found.
# File: 2010_004598 not found.
# File: 2007_006281 not found.
# File: 2010_004521 not found.
# File: 2008_007229 not found.
# File: 2008_001957 not found.
# File: 2008_007981 not found.
# File: 2009_004309 not found.
# File: 2009_000939 not found.
# File: 2008_000860 not found.
# File: 2008_002283 not found.
# File: 2008_006311 not found.
# File: 2008_002067 not found.
# File: 2007_000241 not found.
# File: 2008_003947 not found.
# File: 2010_004107 not found.
# File: 2008_008429 not found.
# File: 2010_002365 not found.
# File: 2010_001550 not found.
# File: 2008_008467 not found.
# File: 2010_003101 not found.
# File: 2009_004329 not found.
# File: 2009_004117 not found.
# File: 2008_002774 not found.
# File: 2010_005087 not found.
# File: 2008_007883 not found.
# File: 2008_003560 not found.
# File: 2010_002705 not found.
# File: 2011_001009 not found.
# File: 2008_005078 not found.
# File: 2008_006873 not found.
# File: 2008_003685 not found.
# File: 2007_006581 not found.
# File: 2010_003238 not found.
# File: 2008_008150 not found.
# File: 2010_006057 not found.
# File: 2009_003383 not found.
# File: 2011_002947 not found.
# File: 2008_005997 not found.
# File: 2011_002507 not found.
# File: 2009_001541 not found.
# File: 2011_001507 not found.
# File: 2011_001245 not found.
# File: 2009_002537 not found.
# File: 2011_001422 not found.
# File: 2010_004363 not found.
# File: 2009_003848 not found.
# File: 2008_004435 not found.
# File: 2010_004108 not found.
# File: 2010_000731 not found.
# File: 2009_000831 not found.
# File: 2008_004969 not found.
# File: 2010_004852 not found.
# File: 2009_002958 not found.
# File: 2008_005682 not found.
# File: 2007_005647 not found.
# File: 2008_006401 not found.
# File: 2010_001025 not found.
# File: 2007_006303 not found.
# File: 2008_008714 not found.
# File: 2008_000535 not found.
# File: 2009_004671 not found.
# File: 2008_005494 not found.
# File: 2011_001505 not found.
# File: 2010_001794 not found.
# File: 2008_008028 not found.
# File: 2008_003829 not found.
# File: 2010_004216 not found.
# File: 2010_004451 not found.
# File: 2011_002409 not found.
# File: 2010_005457 not found.
# File: 2009_002457 not found.
# File: 2007_009464 not found.
# File: 2008_002080 not found.
# File: 2010_005960 not found.
# File: 2010_001533 not found.
# File: 2008_004752 not found.
# File: 2008_002116 not found.
# File: 2008_005178 not found.
# File: 2009_003537 not found.
# File: 2009_002739 not found.
# File: 2009_001052 not found.
# File: 2010_004878 not found.
# File: 2010_004503 not found.
# File: 2009_003039 not found.
# File: 2008_008057 not found.
# File: 2009_000157 not found.
# File: 2010_004597 not found.
# File: 2008_000142 not found.
# File: 2009_000337 not found.
# File: 2011_002236 not found.
# File: 2008_007947 not found.
# File: 2011_002598 not found.
# File: 2008_007054 not found.
# File: 2009_002465 not found.
# File: 2010_000613 not found.
# File: 2008_005685 not found.
# File: 2008_005634 not found.
# File: 2008_007287 not found.
# File: 2009_001085 not found.
# File: 2008_001257 not found.
# File: 2008_008180 not found.
# File: 2008_003534 not found.
# File: 2008_006625 not found.
# File: 2010_003801 not found.
# File: 2011_001399 not found.
# File: 2008_007599 not found.
# File: 2008_004427 not found.
# File: 2010_001119 not found.
# File: 2009_004587 not found.
# File: 2008_002562 not found.
# File: 2011_003151 not found.
# File: 2008_005309 not found.
# File: 2008_006969 not found.
# File: 2008_006808 not found.
# File: 2010_004445 not found.
# File: 2011_000765 not found.
# File: 2010_002456 not found.
# File: 2008_006631 not found.
# File: 2008_006657 not found.
# File: 2009_004283 not found.
# File: 2011_001989 not found.
# File: 2011_003027 not found.
# File: 2010_002320 not found.
# File: 2008_006488 not found.
# File: 2009_004129 not found.
# File: 2009_001260 not found.
# File: 2009_004897 not found.
# File: 2008_002954 not found.
# File: 2011_001223 not found.
# File: 2008_006623 not found.
# File: 2009_000794 not found.
# File: 2010_002469 not found.
# File: 2008_007524 not found.
# File: 2008_002965 not found.
# File: 2011_002811 not found.
# File: 2008_002035 not found.
# File: 2010_003538 not found.
# File: 2009_002153 not found.
# File: 2009_003555 not found.
# File: 2009_000420 not found.
# File: 2011_001320 not found.
# File: 2008_007252 not found.
# File: 2009_001801 not found.
# File: 2010_003579 not found.
# File: 2009_002605 not found.
# File: 2008_000381 not found.
# File: 2011_003171 not found.
# File: 2008_004985 not found.
# File: 2009_002460 not found.
# File: 2011_000376 not found.
# File: 2007_009605 not found.
# File: 2009_001177 not found.
# File: 2010_004770 not found.
# File: 2010_000773 not found.
# File: 2008_000217 not found.
# File: 2011_001163 not found.
# File: 2010_002501 not found.
# File: 2008_005296 not found.
# File: 2010_004048 not found.
# File: 2011_003038 not found.
# File: 2011_003177 not found.
# File: 2010_001139 not found.
# File: 2011_000627 not found.
# File: 2010_003949 not found.
# File: 2010_001671 not found.
# File: 2010_005239 not found.
# File: 2011_001166 not found.
# File: 2009_000889 not found.
# File: 2008_007831 not found.
# File: 2008_000283 not found.
# File: 2008_000219 not found.
# File: 2009_002229 not found.
# File: 2009_001323 not found.
# File: 2009_002770 not found.
# File: 2010_001896 not found.
# File: 2008_004014 not found.
# File: 2008_003729 not found.
# File: 2010_004027 not found.
# File: 2010_002786 not found.
# File: 2011_002561 not found.
# File: 2008_002575 not found.
# File: 2009_002204 not found.
# File: 2010_001535 not found.
# File: 2008_008363 not found.
# File: 2008_001655 not found.
# File: 2010_001560 not found.
# File: 2009_004836 not found.
# File: 2010_004071 not found.
# File: 2008_006511 not found.
# File: 2009_000367 not found.
# File: 2010_002853 not found.
# File: 2011_000559 not found.
# File: 2009_001660 not found.
# File: 2009_005051 not found.
# File: 2011_000095 not found.
# File: 2008_004833 not found.
# File: 2008_006908 not found.
# File: 2009_001884 not found.
# File: 2008_000764 not found.
# File: 2008_000547 not found.
# File: 2009_003713 not found.
# File: 2011_002046 not found.
# File: 2010_002583 not found.
# File: 2008_007730 not found.
# File: 2008_003922 not found.
# File: 2010_002041 not found.
# File: 2009_002667 not found.
# File: 2008_008170 not found.
# File: 2008_006855 not found.
# File: 2010_005426 not found.
# File: 2008_001056 not found.
# File: 2011_001375 not found.
# File: 2009_000748 not found.
# File: 2011_000307 not found.
# File: 2007_008218 not found.
# File: 2009_004174 not found.
# File: 2008_001294 not found.
# File: 2009_002416 not found.
# File: 2008_002848 not found.
# File: 2011_001625 not found.
# File: 2011_002767 not found.
# File: 2009_001549 not found.
# File: 2007_002142 not found.
# File: 2008_008262 not found.
# File: 2008_005916 not found.
# File: 2008_002278 not found.
# File: 2009_003377 not found.
# File: 2008_000979 not found.
# File: 2010_002425 not found.
# File: 2009_001555 not found.
# File: 2008_004841 not found.
# File: 2010_005949 not found.
# File: 2008_000953 not found.
# File: 2008_008227 not found.
# File: 2007_002227 not found.
# File: 2009_003784 not found.
# File: 2008_005589 not found.
# File: 2008_005123 not found.
# File: 2010_002993 not found.
# File: 2008_003049 not found.
# File: 2008_005560 not found.
# File: 2010_004130 not found.
# File: 2008_001543 not found.
# File: 2009_003127 not found.
# File: 2009_004454 not found.
# File: 2008_002193 not found.
# File: 2009_000445 not found.
# File: 2008_003892 not found.
# File: 2010_001111 not found.
# File: 2009_000105 not found.
# File: 2009_003012 not found.
# File: 2010_005068 not found.
# File: 2008_007875 not found.
# File: 2007_000170 not found.
# File: 2010_003954 not found.
# File: 2011_001097 not found.
# File: 2010_003687 not found.
# File: 2010_004306 not found.
# File: 2011_002388 not found.
# File: 2009_004207 not found.
# File: 2011_001283 not found.
# File: 2008_004763 not found.
# File: 2010_004345 not found.
# File: 2009_003543 not found.
# File: 2011_002012 not found.
# File: 2008_005036 not found.
# File: 2008_007949 not found.
# File: 2010_003169 not found.
# File: 2008_006778 not found.
# File: 2008_002296 not found.
# File: 2009_000631 not found.
# File: 2008_008541 not found.
# File: 2008_006939 not found.
# File: 2009_001917 not found.
# File: 2009_002831 not found.
# File: 2009_004058 not found.
# File: 2009_000696 not found.
# File: 2009_003183 not found.
# File: 2008_005817 not found.
# File: 2008_000742 not found.
# File: 2008_006954 not found.
# File: 2008_001690 not found.
# File: 2009_004112 not found.
# File: 2011_002131 not found.
# File: 2010_002315 not found.
# File: 2009_002240 not found.
# File: 2008_006591 not found.
# File: 2008_005431 not found.
# File: 2011_002609 not found.
# File: 2008_006347 not found.
# File: 2008_006950 not found.
# File: 2009_002565 not found.
# File: 2009_002211 not found.
# File: 2008_006857 not found.
# File: 2009_001812 not found.
# File: 2009_002452 not found.
# File: 2008_005496 not found.
# File: 2010_000463 not found.
# File: 2009_003739 not found.
# File: 2008_000403 not found.
# File: 2011_001715 not found.
# File: 2008_006071 not found.
# File: 2008_004003 not found.
# File: 2010_002527 not found.
# File: 2010_003539 not found.
# File: 2009_004871 not found.
# File: 2010_004938 not found.
# File: 2008_000985 not found.
# File: 2009_000161 not found.
# File: 2008_007004 not found.
# File: 2009_002515 not found.
# File: 2008_004937 not found.
# File: 2008_006409 not found.
# File: 2011_000345 not found.
# File: 2009_001615 not found.
# File: 2010_004665 not found.
# File: 2008_004232 not found.
# File: 2010_002121 not found.
# File: 2008_002817 not found.
# File: 2008_000672 not found.
# File: 2008_001267 not found.
# File: 2008_005065 not found.
# File: 2009_003873 not found.
# File: 2008_003231 not found.
# File: 2008_006179 not found.
# File: 2009_005035 not found.
# File: 2008_002335 not found.
# File: 2010_001085 not found.
# File: 2008_003688 not found.
# File: 2008_003659 not found.
# File: 2008_002487 not found.
# File: 2009_002151 not found.
# File: 2008_000236 not found.
# File: 2008_004719 not found.
# File: 2009_003468 not found.
# File: 2007_009889 not found.
# File: 2008_003143 not found.
# File: 2009_003883 not found.
# File: 2008_004616 not found.
# File: 2009_004141 not found.
# File: 2009_002438 not found.
# File: 2010_002042 not found.
# File: 2011_002552 not found.
# File: 2008_008382 not found.
# File: 2009_004514 not found.
# File: 2010_001360 not found.
# File: 2008_004834 not found.
# File: 2008_002357 not found.
# File: 2011_000152 not found.
# File: 2008_004106 not found.
# File: 2010_003174 not found.
# File: 2008_003452 not found.
# File: 2009_000028 not found.
# File: 2010_000204 not found.
# File: 2008_003914 not found.
# File: 2011_002218 not found.
# File: 2009_000910 not found.
# File: 2008_007611 not found.
# File: 2011_001641 not found.
# File: 2007_000364 not found.
# File: 2010_001580 not found.
# File: 2011_001335 not found.
# File: 2008_008324 not found.
# File: 2008_003343 not found.
# File: 2008_000197 not found.
# File: 2008_003224 not found.
# File: 2009_001056 not found.
# File: 2010_004123 not found.
# File: 2010_005807 not found.
# File: 2008_000154 not found.
# File: 2010_004043 not found.
# File: 2009_002406 not found.
# File: 2008_000493 not found.
# File: 2010_000261 not found.
# File: 2011_000753 not found.
# File: 2008_006039 not found.
# File: 2007_001724 not found.
# File: 2008_002405 not found.
# File: 2011_000329 not found.
# File: 2010_004052 not found.
# File: 2007_007649 not found.
# File: 2010_000133 not found.
# File: 2011_002389 not found.
# File: 2008_001227 not found.
# File: 2009_003469 not found.
# File: 2010_004909 not found.
# File: 2010_005223 not found.
# File: 2009_002145 not found.
# File: 2009_004839 not found.
# File: 2010_001305 not found.
# File: 2010_001449 not found.
# File: 2009_002620 not found.
# File: 2011_001771 not found.
# File: 2010_002255 not found.
# File: 2008_006404 not found.
# File: 2010_001225 not found.
# File: 2008_006881 not found.
# File: 2008_001445 not found.
# File: 2009_004171 not found.
# File: 2007_002105 not found.
# File: 2008_002017 not found.
# File: 2008_008020 not found.
# File: 2011_003169 not found.
# File: 2009_000804 not found.
# File: 2011_002953 not found.
# File: 2010_004945 not found.
# File: 2010_000971 not found.
# File: 2009_002335 not found.
# File: 2010_004447 not found.
# File: 2010_004655 not found.
# File: 2011_001521 not found.
# File: 2008_003925 not found.
# File: 2008_006140 not found.
# File: 2008_004663 not found.
# File: 2011_002457 not found.
# File: 2009_003156 not found.
# File: 2010_001929 not found.
# File: 2009_001282 not found.
# File: 2010_004806 not found.
# File: 2009_004037 not found.
# File: 2008_003881 not found.
# File: 2011_000061 not found.
# File: 2010_003939 not found.
# File: 2008_002647 not found.
# File: 2009_002609 not found.
# File: 2008_003265 not found.
# File: 2010_002191 not found.
# File: 2010_005833 not found.
# File: 2011_002697 not found.
# File: 2008_002244 not found.
# File: 2008_003043 not found.
# File: 2010_005364 not found.
# File: 2008_005668 not found.
# File: 2010_002113 not found.
# File: 2010_004436 not found.
# File: 2008_002776 not found.
# File: 2010_001480 not found.
# File: 2010_002015 not found.
# File: 2008_002001 not found.
# File: 2009_003458 not found.
# File: 2008_001813 not found.
# File: 2009_005001 not found.
# File: 2010_000897 not found.
# File: 2010_000803 not found.
# File: 2009_002523 not found.
# File: 2008_001302 not found.
# File: 2009_004797 not found.
# File: 2010_000375 not found.
# File: 2009_001826 not found.
# File: 2009_001709 not found.
# File: 2011_001052 not found.
# File: 2008_003667 not found.
# File: 2008_005626 not found.
# File: 2010_004455 not found.
# File: 2010_003197 not found.
# File: 2007_005212 not found.
# File: 2008_003585 not found.
# File: 2007_009436 not found.
# File: 2008_000716 not found.
# File: 2008_005015 not found.
# File: 2008_001691 not found.
# File: 2008_003745 not found.
# File: 2009_002519 not found.
# File: 2010_003887 not found.
# File: 2010_003651 not found.
# File: 2009_003168 not found.
# File: 2009_003668 not found.
# File: 2011_001885 not found.
# File: 2011_002291 not found.
# File: 2008_003151 not found.
# File: 2008_006211 not found.
# File: 2008_005362 not found.
# File: 2010_002457 not found.
# File: 2011_002039 not found.
# File: 2009_001395 not found.
# File: 2010_000386 not found.
# File: 2010_002185 not found.
# File: 2007_004500 not found.
# File: 2009_004096 not found.
# File: 2008_006750 not found.
# File: 2008_002930 not found.
# File: 2009_003351 not found.
# File: 2009_001635 not found.
# File: 2008_005677 not found.
# File: 2008_002961 not found.
# File: 2010_001689 not found.
# File: 2009_000486 not found.
# File: 2008_003417 not found.
# File: 2008_000723 not found.
# File: 2008_004110 not found.
# File: 2008_003449 not found.
# File: 2010_004717 not found.
# File: 2009_002879 not found.
# File: 2008_005136 not found.
# File: 2009_000930 not found.
# File: 2008_008635 not found.
# File: 2008_003039 not found.
# End of TfRecord. Total of image written: 0
